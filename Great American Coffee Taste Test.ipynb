# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\USER\\Downloads\\Great+American+Coffee+Taste+Test\\Coffee_survey.csv")

# %%
df.info()
pd.set_option('display.max_columns',111)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4042 entries, 0 to 4041
# Columns: 111 entries, Submission ID to Political Affiliation
# dtypes: float64(21), object(90)
# memory usage: 3.4+ MB

# %%
df
# Out:
#      Submission ID What is your age?  \
# 0           gMR29l   18-24 years old
# 1           BkPN0e   25-34 years old
# 2           W5G8jj   25-34 years old
# 3           4xWgGr   35-44 years old
# 4           QD27Q8   25-34 years old
# ...            ...               ...
# 4037        PA44VP     >65 years old
# 4038        vNgpPD     >65 years old
# 4039        g5ggRM   18-24 years old
# 4040        rlgbDN   25-34 years old
# 4041        0EGYe9   25-34 years old
#
#      How many cups of coffee do you typically drink per day?  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4037                                                  2
# ...

# %%
df[['Ethnicity/Race','Gender','Education Level','What is your age?','How many cups of coffee do you typically drink per day?']].iloc[4037:4042]
# Out:
#        Ethnicity/Race  Gender                     Education Level  \
# 4037  White/Caucasian  Female                     Master's degree
# 4038  White/Caucasian    Male                   Bachelor's degree
# 4039  White/Caucasian    Male  Some college or associate's degree
# 4040  White/Caucasian    Male                   Bachelor's degree
# 4041  White/Caucasian  Female    Doctorate or professional degree
#
#      What is your age? How many cups of coffee do you typically drink per day?
# 4037     >65 years old                                                  2
# 4038     >65 years old                                                  2
# 4039   18-24 years old                                                  1
# 4040   25-34 years old                                                  2
# 4041   25-34 years old                                                  1

# %%
df.iloc[[4037,4041]]
# Out:
#      Submission ID What is your age?  \
# 4037        PA44VP     >65 years old
# 4041        0EGYe9   25-34 years old
#
#      How many cups of coffee do you typically drink per day?  \
# 4037                                                  2
# 4041                                                  1
#
#      Where do you typically drink coffee?  \
# 4037                              At home
# 4041                              At home
#
#      Where do you typically drink coffee? (At home)  \
# 4037                                           True
# 4041                                           True
#
#      Where do you typically drink coffee? (At the office)  \
# 4037                                              False
# 4041                                              False
#
#      Where do you typically drink coffee? (On the go)  \
# 4037                                            False
# 4041                                            False
#
# ...

# %%
df['Do you usually add anything to your coffee? (Other)'].value_counts()
###3914 don't add anything to their coffe while 46 people do ###
# Out:
# Do you usually add anything to your coffee? (Other)
# False    3914
# True       46
# Name: count, dtype: int64

# %%
df.loc[[0,1]]
# Out:
#   Submission ID What is your age?  \
# 0        gMR29l   18-24 years old
# 1        BkPN0e   25-34 years old
#
#   How many cups of coffee do you typically drink per day?  \
# 0                                                NaN
# 1                                                NaN
#
#   Where do you typically drink coffee?  \
# 0                                  NaN
# 1                                  NaN
#
#   Where do you typically drink coffee? (At home)  \
# 0                                            NaN
# 1                                            NaN
#
#   Where do you typically drink coffee? (At the office)  \
# 0                                                NaN
# 1                                                NaN
#
#   Where do you typically drink coffee? (On the go)  \
# 0                                              NaN
# 1                                              NaN
#
#   Where do you typically drink coffee? (At a cafe)  \
# ...

# %%
add_coffee=df.loc[0:,'Do you usually add anything to your coffee? (No - just black)':'Do you usually add anything to your coffee? (Other)']

# %%
add_coffee
# Out:
#      Do you usually add anything to your coffee? (No - just black)  \
# 0                                                  True
# 1                                                  True
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 4037                                              False
# 4038                                              False
# 4039                                               True
# 4040                                              False
# 4041                                              False
#
#      Do you usually add anything to your coffee? (Milk, dairy alternative, or coffee creamer)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# ...

# %%
black_coffee_preference=add_coffee['Do you usually add anything to your coffee? (No - just black)']

# %%
black_coffee_preference.value_counts()
# Out:
# Do you usually add anything to your coffee? (No - just black)
# True     2611
# False    1349
# Name: count, dtype: int64

# %%
#2611 people prefer their coffee black, while 1349 people do not ###

# %%
Add_milk=add_coffee['Do you usually add anything to your coffee? (Milk, dairy alternative, or coffee creamer)']

# %%
Add_milk.value_counts()
# Out:
# Do you usually add anything to your coffee? (Milk, dairy alternative, or coffee creamer)
# False    2260
# True     1700
# Name: count, dtype: int64

# %%
### 1700 people prefer to add Milk,diary alternatives or coffee creamer to their coffee###

# %%
Sugar_Sweetner=add_coffee['Do you usually add anything to your coffee? (Sugar or sweetener)']

# %%
Sugar_Sweetner.value_counts()
# Out:
# Do you usually add anything to your coffee? (Sugar or sweetener)
# False    3445
# True      515
# Name: count, dtype: int64

# %%
### 515 people add Sugar or Sweetner to their Coffee while 3445 do not###

# %%
df
# Out:
#      Submission ID What is your age?  \
# 0           gMR29l   18-24 years old
# 1           BkPN0e   25-34 years old
# 2           W5G8jj   25-34 years old
# 3           4xWgGr   35-44 years old
# 4           QD27Q8   25-34 years old
# ...            ...               ...
# 4037        PA44VP     >65 years old
# 4038        vNgpPD     >65 years old
# 4039        g5ggRM   18-24 years old
# 4040        rlgbDN   25-34 years old
# 4041        0EGYe9   25-34 years old
#
#      How many cups of coffee do you typically drink per day?  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4037                                                  2
# ...

# %%
add_coffee=add_coffee.apply(pd.value_counts)

# %%
add_coffee
# Out:
#        Do you usually add anything to your coffee? (No - just black)  \
# False                                               1349
# True                                                2611
#
#        Do you usually add anything to your coffee? (Milk, dairy alternative, or coffee creamer)  \
# False                                               2260
# True                                                1700
#
#        Do you usually add anything to your coffee? (Sugar or sweetener)  \
# False                                               3445
# True                                                 515
#
#        Do you usually add anything to your coffee? (Flavor syrup)  \
# False                                               3729
# True                                                 231
#
#        Do you usually add anything to your coffee? (Other)
# False                                               3914
# True                                                  46

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib as mpl
import
# Out:
#   Cell In[50], line 2
#     import
#           ^
# SyntaxError: invalid syntax

# %%
plt.Subplot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 plt.Subplot()
#
# TypeError: _AxesBase.__init__() missing 1 required positional argument: 'fig'

# %%
df.set_index()

# %%
Coffee_preference=df[['What roast level of coffee do you prefer?','Lastly, what was your favorite overall coffee?']]

# %%
Coffee_preference
# Out:
#      What roast level of coffee do you prefer?  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 4037                                    Medium
# 4038                                     Light
# 4039                                     Light
# 4040                                    Medium
# 4041                                    Medium
#
#      Lastly, what was your favorite overall coffee?
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# ...

# %%
Coffee_preference=Coffee_preference.dropna()

# %%
Coffee_preference
# Out:
#      What roast level of coffee do you prefer?  \
# 15                                       Light
# 16                                      Blonde
# 17                                      Medium
# 19                                      Nordic
# 34                                       Light
# ...                                        ...
# 4037                                    Medium
# 4038                                     Light
# 4039                                     Light
# 4040                                    Medium
# 4041                                    Medium
#
#      Lastly, what was your favorite overall coffee?
# 15                                         Coffee B
# 16                                         Coffee D
# 17                                         Coffee B
# 19                                         Coffee A
# 34                                         Coffee B
# ...                                             ...
# ...

# %%
Light_A=Coffee_preference[(Coffee_preference['What roast level of coffee do you prefer?']
=='Light')&(Coffee_preference['Lastly, what was your favorite overall coffee?']=='Coffee A')]

# %%
Light_A
# Out:
#      What roast level of coffee do you prefer?  \
# 41                                       Light
# 71                                       Light
# 72                                       Light
# 75                                       Light
# 84                                       Light
# ...                                        ...
# 4019                                     Light
# 4025                                     Light
# 4026                                     Light
# 4032                                     Light
# 4038                                     Light
#
#      Lastly, what was your favorite overall coffee?
# 41                                         Coffee A
# 71                                         Coffee A
# 72                                         Coffee A
# 75                                         Coffee A
# 84                                         Coffee A
# ...                                             ...
# ...

# %%
Light_A.count()
# Out:
# What roast level of coffee do you prefer?         435
# Lastly, what was your favorite overall coffee?    435
# dtype: int64

# %%
###  from the survey 435 Americans prefer Light(A) Coffee ###

# %%
Medium_B=Coffee_preference[(Coffee_preference['What roast level of coffee do you prefer?']
=='Medium')&(Coffee_preference['Lastly, what was your favorite overall coffee?']=='Coffee B')]

# %%
Medium_B
# Out:
#      What roast level of coffee do you prefer?  \
# 17                                      Medium
# 50                                      Medium
# 78                                      Medium
# 104                                     Medium
# 113                                     Medium
# ...                                        ...
# 3980                                    Medium
# 3981                                    Medium
# 3993                                    Medium
# 4010                                    Medium
# 4029                                    Medium
#
#      Lastly, what was your favorite overall coffee?
# 17                                         Coffee B
# 50                                         Coffee B
# 78                                         Coffee B
# 104                                        Coffee B
# 113                                        Coffee B
# ...                                             ...
# ...

# %%
### From the survey 415 Americans prefer  Medium(B) Coffee ###

# %%
Dark_C=Coffee_preference[(Coffee_preference['What roast level of coffee do you prefer?']
=='Dark')&(Coffee_preference['Lastly, what was your favorite overall coffee?']=='Coffee C')]

# %%
Dark_C
# Out:
#      What roast level of coffee do you prefer?  \
# 40                                        Dark
# 106                                       Dark
# 148                                       Dark
# 190                                       Dark
# 246                                       Dark
# ...                                        ...
# 3963                                      Dark
# 3974                                      Dark
# 3987                                      Dark
# 4022                                      Dark
# 4033                                      Dark
#
#      Lastly, what was your favorite overall coffee?
# 40                                         Coffee C
# 106                                        Coffee C
# 148                                        Coffee C
# 190                                        Coffee C
# 246                                        Coffee C
# ...                                             ...
# ...

# %%
### From the survey 128 Americans prefer Dark(C) Coffee ##

# %% [markdown]
# #Coffee preference by Age distribution

# %%
Age_Coffee=df[['What is your age?','Lastly, what was your favorite overall coffee?','What roast level of coffee do you prefer?']]

# %%
Age_Coffee
# Out:
#      What is your age? Lastly, what was your favorite overall coffee?  \
# 0      18-24 years old                                            NaN
# 1      25-34 years old                                            NaN
# 2      25-34 years old                                            NaN
# 3      35-44 years old                                            NaN
# 4      25-34 years old                                            NaN
# ...                ...                                            ...
# 4037     >65 years old                                       Coffee A
# 4038     >65 years old                                       Coffee A
# 4039   18-24 years old                                       Coffee C
# 4040   25-34 years old                                       Coffee A
# 4041   25-34 years old                                       Coffee A
#
#      What roast level of coffee do you prefer?
# 0                                          NaN
# ...

# %%
Age_Coffee.dropna()
# Out:
#      What is your age? Lastly, what was your favorite overall coffee?  \
# 15       <18 years old                                       Coffee B
# 16       >65 years old                                       Coffee D
# 17     25-34 years old                                       Coffee B
# 19     18-24 years old                                       Coffee A
# 34     45-54 years old                                       Coffee B
# ...                ...                                            ...
# 4037     >65 years old                                       Coffee A
# 4038     >65 years old                                       Coffee A
# 4039   18-24 years old                                       Coffee C
# 4040   25-34 years old                                       Coffee A
# 4041   25-34 years old                                       Coffee A
#
#      What roast level of coffee do you prefer?
# 15                                       Light
# ...

# %%
Age_Coffee['What is your age?'].unique()
# Out:
# array(['18-24 years old', '25-34 years old', '35-44 years old',
#        '55-64 years old', nan, '<18 years old', '>65 years old',
#        '45-54 years old'], dtype=object)

# %%
Age_Coffee=Age_Coffee.replace('nan',np.nan)

# %%
Age_Coffee=Age_Coffee.dropna()

# %%
Age_Coffee
# Out:
#      What is your age? Lastly, what was your favorite overall coffee?  \
# 15       <18 years old                                       Coffee B
# 16       >65 years old                                       Coffee D
# 17     25-34 years old                                       Coffee B
# 19     18-24 years old                                       Coffee A
# 34     45-54 years old                                       Coffee B
# ...                ...                                            ...
# 4037     >65 years old                                       Coffee A
# 4038     >65 years old                                       Coffee A
# 4039   18-24 years old                                       Coffee C
# 4040   25-34 years old                                       Coffee A
# 4041   25-34 years old                                       Coffee A
#
#      What roast level of coffee do you prefer?
# 15                                       Light
# ...

# %%
Age_Coffee['What is your age?']=pd.Categorical(['What is your age?'],categories =['<18 years old', '>65 years old', '25-34 years old', '18-24 years old', '45-54 years old','35-44 years old','55-64 years old'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 Age_Coffee['What is your age?']=pd.Categorical(['What is your age?'],categories =['<18 years old', '>65 years old', '25-34 years old', '18-24 years old', '45-54 years old','35-44 years old','55-64 years old'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3950, in DataFrame.__setitem__(self, key, value)
#    3947     self._setitem_array([key], value)
#    3948 else:
#    3949     # set column
# -> 3950     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4143, in DataFrame._set_item(self, key, value)
#    4133 def _set_item(self, key, value) -> None:
#    4134     """
#    4135     Add series to DataFrame in specified column.
#    4136
#    (...)
#    4141     ensure homogeneity.
#    4142     """
# -> 4143     value = self._sanitize_column(value)
# ...

# %%
Age_Coffee=pd.DataFrame(Age_Coffee)

# %%
Age_Coffee
# Out:
#      What is your age? Lastly, what was your favorite overall coffee?  \
# 15       <18 years old                                       Coffee B
# 16       >65 years old                                       Coffee D
# 17     25-34 years old                                       Coffee B
# 19     18-24 years old                                       Coffee A
# 34     45-54 years old                                       Coffee B
# ...                ...                                            ...
# 4037     >65 years old                                       Coffee A
# 4038     >65 years old                                       Coffee A
# 4039   18-24 years old                                       Coffee C
# 4040   25-34 years old                                       Coffee A
# 4041   25-34 years old                                       Coffee A
#
#      What roast level of coffee do you prefer?
# 15                                       Light
# ...

# %%
Age_Coffee['What is your age?'].unique()
# Out:
# array(['<18 years old', '>65 years old', '25-34 years old',
#        '18-24 years old', '45-54 years old', '35-44 years old',
#        '55-64 years old'], dtype=object)

# %%
categories = ['<18 years old', '>65 years old', '25-34 years old', '18-24 years old', '45-54 years old','35-44 years old','55-64 years old']

# %%
categories = categories * len(Age_Coffee.index)

# %%
if len(categories) != len(Age_Coffee):
    raise ValueError("Length of categories must match the length of the DataFrame")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 2
#       1 if len(categories) != len(Age_Coffee):
# ----> 2     raise ValueError("Length of categories must match the length of the DataFrame")
#
# ValueError: Length of categories must match the length of the DataFrame

# %%
Age_Coffee.loc[0, 'What is your age?'] = '<18 years old'

# %%
Age_Coffee['What is your age?'] = pd.Categorical(Age_Coffee['What is your age?'], categories=['<18 years old', '>65 years old', '25-34 years old', '18-24 years old', '45-54 years old','35-44 years old','55-64 years old'])

# %%
ct = pd.crosstab(Age_Coffee['What is your age?'], Age_Coffee['What roast level of coffee do you prefer?'])

# %%
plt.figure(figsize=(10, 5))
ct.plot(kind='bar', stacked=False)
plt.title('Roast Level Preferences by Age Group')
plt.xlabel('What is your age?')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Roast Level')
plt.show()

# %%
cl = pd.crosstab(Age_Coffee['What is your age?'], Age_Coffee['Lastly, what was your favorite overall coffee?'])

# %%
plt.figure(figsize=(10, 6))
cl.plot(kind='bar', stacked=False)
plt.title('Favorite Coffee by Age Group')
plt.xlabel('What is your age?')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Coffee Type')
plt.show()

# %%
Age_Coffee.columns=['Age','Favorite_Coffee','Favorite_Roast']

# %%
Age_Coffee=Age_Coffee.dropna()

# %%
m1=sns.distplot(Age_Coffee.Favorite_Coffee,bins=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 m1=sns.distplot(Age_Coffee.Favorite_Coffee,bins=15)
#
# NameError: name 'sns' is not defined

# %%
Age_Coffee
# Out:
#                   Age Favorite_Coffee Favorite_Roast
# 15      <18 years old        Coffee B          Light
# 16      >65 years old        Coffee D         Blonde
# 17    25-34 years old        Coffee B         Medium
# 19    18-24 years old        Coffee A         Nordic
# 34    45-54 years old        Coffee B          Light
# ...               ...             ...            ...
# 4037    >65 years old        Coffee A         Medium
# 4038    >65 years old        Coffee A          Light
# 4039  18-24 years old        Coffee C          Light
# 4040  25-34 years old        Coffee A         Medium
# 4041  25-34 years old        Coffee A         Medium
#
# [3767 rows x 3 columns]

# %%
less_eighteen_BL=(Age_Coffee.Age=='<18 years old')& (Age_Coffee.Favorite_Coffee=='Coffee B')&(Age_Coffee.Favorite_Roast=='Light')
less_eighteen_BM=(Age_Coffee.Age=='<18 years old')& (Age_Coffee.Favorite_Coffee=='Coffee B')&(Age_Coffee.Favorite_Roast=='Medium')
less_eighteen_BD=(Age_Coffee.Age=='<18 years old')& (Age_Coffee.Favorite_Coffee=='Coffee B')&(Age_Coffee.Favorite_Roast=='Dark')

# %%
less_eighteen_BL.value_counts()
less_eighteen_BM.value_counts()
less_eighteen_BD.value_counts()
# Out:
# False    3767
# Name: count, dtype: int64

# %%
less_eighteen_BL.value_counts()
# Out:
# False    3766
# True        1
# Name: count, dtype: int64

# %%
less_eighteen_BM.value_counts()
# Out:
# False    3765
# True        2
# Name: count, dtype: int64

# %%
less_eighteen_BD.value_counts()
# Out:
# False    3767
# Name: count, dtype: int64

# %%
less_eighteen_A=(Age_Coffee.Age=='<18 years old')& (Age_Coffee.Favorite_Coffee=='Coffee A')
less_eighteen_A.value_counts()
# Out:
# False    3763
# True        4
# Name: count, dtype: int64

# %%
less_eighteen_C=(Age_Coffee.Age=='<18 years old')& (Age_Coffee.Favorite_Coffee=='Coffee C')
less_eighteen_C.value_counts()
# Out:
# False    3764
# True        3
# Name: count, dtype: int64

# %%
less_eighteen_D=(Age_Coffee.Age=='<18 years old')& (Age_Coffee.Favorite_Coffee=='Coffee D')
less_eighteen_D.value_counts()
# Out:
# False    3762
# True        5
# Name: count, dtype: int64

# %%
less_eighteen_BL=(Age_Coffee.Age=='<18 years old')& (Age_Coffee.Favorite_Coffee=='Coffee B')&(Age_Coffee.Favorite_Roast=='Light')

# %%
less_eighteen_BL.value_counts()
# Out:
# False    3766
# True        1
# Name: count, dtype: int64

# %%
df
# Out:
#      Submission ID What is your age?  \
# 0           gMR29l   18-24 years old
# 1           BkPN0e   25-34 years old
# 2           W5G8jj   25-34 years old
# 3           4xWgGr   35-44 years old
# 4           QD27Q8   25-34 years old
# ...            ...               ...
# 4037        PA44VP     >65 years old
# 4038        vNgpPD     >65 years old
# 4039        g5ggRM   18-24 years old
# 4040        rlgbDN   25-34 years old
# 4041        0EGYe9   25-34 years old
#
#      How many cups of coffee do you typically drink per day?  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4037                                                  2
# ...

# %%
Employment_status_Preference=df[['Employment Status','Lastly, what was your favorite overall coffee?','What roast level of coffee do you prefer?']]

# %%
Employment_status_Preference
# Out:
#        Employment Status Lastly, what was your favorite overall coffee?  \
# 0                    NaN                                            NaN
# 1                    NaN                                            NaN
# 2                    NaN                                            NaN
# 3                    NaN                                            NaN
# 4                    NaN                                            NaN
# ...                  ...                                            ...
# 4037             Retired                                       Coffee A
# 4038             Retired                                       Coffee A
# 4039  Employed full-time                                       Coffee C
# 4040          Unemployed                                       Coffee A
# 4041  Employed full-time                                       Coffee A
#
#      What roast level of coffee do you prefer?
# 0                                          NaN
# ...

# %%
Employment_status_Preference=Employment_status_Preference.dropna()

# %%
Employment_status_Preference
# Out:
#        Employment Status Lastly, what was your favorite overall coffee?  \
# 15    Employed full-time                                       Coffee B
# 17    Employed full-time                                       Coffee B
# 34    Employed full-time                                       Coffee B
# 41            Unemployed                                       Coffee A
# 42    Employed full-time                                       Coffee D
# ...                  ...                                            ...
# 4037             Retired                                       Coffee A
# 4038             Retired                                       Coffee A
# 4039  Employed full-time                                       Coffee C
# 4040          Unemployed                                       Coffee A
# 4041  Employed full-time                                       Coffee A
#
#      What roast level of coffee do you prefer?
# 15                                       Light
# ...

# %%
Employment_status_Preference.columns=['Employement Status','Favorite_Coffee','Roast_level']

# %%
Employment_status_Preference
# Out:
#       Employement Status Favorite_Coffee Roast_level
# 15    Employed full-time        Coffee B       Light
# 17    Employed full-time        Coffee B      Medium
# 34    Employed full-time        Coffee B       Light
# 41            Unemployed        Coffee A       Light
# 42    Employed full-time        Coffee D       Light
# ...                  ...             ...         ...
# 4037             Retired        Coffee A      Medium
# 4038             Retired        Coffee A       Light
# 4039  Employed full-time        Coffee C       Light
# 4040          Unemployed        Coffee A      Medium
# 4041  Employed full-time        Coffee A      Medium
#
# [3419 rows x 3 columns]

# %%
Employment_status_Preference['Employement Status'].unique()
# Out:
# array(['Employed full-time', 'Unemployed', 'Student',
#        'Employed part-time', 'Retired', 'Homemaker'], dtype=object)

# %%
Employment_status_Preference['Employement Status']=pd.Categorical(['Employement Status'],categories=['Employed full-time', 'Unemployed', 'Student', 'Employed part-time', 'Retired', 'Homemaker'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 Employment_status_Preference['Employement Status']=pd.Categorical(['Employement Status'],categories=['Employed full-time', 'Unemployed', 'Student', 'Employed part-time', 'Retired', 'Homemaker'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3950, in DataFrame.__setitem__(self, key, value)
#    3947     self._setitem_array([key], value)
#    3948 else:
#    3949     # set column
# -> 3950     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4143, in DataFrame._set_item(self, key, value)
#    4133 def _set_item(self, key, value) -> None:
#    4134     """
#    4135     Add series to DataFrame in specified column.
#    4136
#    (...)
#    4141     ensure homogeneity.
#    4142     """
# -> 4143     value = self._sanitize_column(value)
# ...

# %%
dy = pd.crosstab(Employment_status_Preference['Employement Status'], Employment_status_Preference['Favorite_Coffee'])

# %%
plt.figure(figsize=(10, 5))
dy.plot(kind='bar', stacked=False)
plt.title('Favorite Coffee by Employement Status')
plt.xlabel('Employement Status')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Favorite Coffee')
plt.show()

# %%
Coffee_d_status=(Employment_status_Preference.Employement Status=='Employed full-time') & (Employment_status_Preference.Favorite_Coffee=='Coffee D')
# Out:
#   Cell In[111], line 1
#     Coffee_d_status=(Employment_status_Preference.Employement Status=='Employed full-time') & (Employment_status_Preference.Favorite_Coffee=='Coffee D')
#                      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
dy = pd.crosstab(Employment_status_Preference['Employement Status'], Employment_status_Preference['Roast_level'])

# %%
plt.figure(figsize=(10, 5))
dy.plot(kind='bar', stacked=False)
plt.title('Roast level by Employement Status')
plt.xlabel('Employement Status')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Roast Level')
plt.show()

# %%
Coffee_d_status=(Employment_status_Preference['Employement Status']=='Employed full-time') & (Employment_status_Preference['Favorite_Coffee']=='Coffee D')

# %%
Coffee_d_status.value_counts()
# Out:
# False    2368
# True     1051
# Name: count, dtype: int64

# %%
###1051 of people employed full time prefer Coffee D ###

# %%
Coffee_A_status=(Employment_status_Preference['Employement Status']=='Employed full-time') &(Employment_status_Preference['Favorite_Coffee']=='Coffee A')

# %%
Coffee_A_status.value_counts()
# Out:
# False    2833
# True      586
# Name: count, dtype: int64

# %%
###586 of people employed full time prefer Coffee A ###

# %%
Coffee_C_status=(Employment_status_Preference['Employement Status']=='Employed full-time') &(Employment_status_Preference['Favorite_Coffee']=='Coffee C')

# %%
Coffee_C_status.value_counts()
# Out:
# False    2879
# True      540
# Name: count, dtype: int64

# %%
### 540 of people employed full time prefer Coffee C ###

# %%
Coffee_B_status=(Employment_status_Preference['Employement Status']=='Employed full-time') &(Employment_status_Preference['Favorite_Coffee']=='Coffee B')

# %%
Coffee_B_status.value_counts()
# Out:
# False    2888
# True      531
# Name: count, dtype: int64

# %%
### 531 of people employed full time prefer Coffee D ###

# %%
pip install nbconvert
# Out:
# ...
#
# ...

# %%
jupyter nbconvert --to html your_notebook.ipynb
# Out:
#   Cell In[126], line 1
#     jupyter nbconvert --to html your_notebook.ipynb
#             ^
# SyntaxError: invalid syntax

# %%
jupyter nbconvert --to pdf Great American Coffee Taste Test .ipynb
# Out:
#   Cell In[127], line 1
#     jupyter nbconvert --to pdf Great American Coffee Taste Test .ipynb
#             ^
# SyntaxError: invalid syntax

# %%
jupyter nbconvert --to pdf "Great American Coffee Taste Test.ipynb"
# Out:
#   Cell In[128], line 1
#     jupyter nbconvert --to pdf "Great American Coffee Taste Test.ipynb"
#             ^
# SyntaxError: invalid syntax
